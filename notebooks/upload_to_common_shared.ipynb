# %%
import os
from docx           import Document

# %%
os.listdir("S:/")
# Out:
# ['.DS_Store',
#  '1. Dr. SPS',
#  '10. Bhanu Kiran',
#  '100. Suvrat chaturvedi',
#  '101. Shuchita Singh',
#  '102. Vikas Jain',
#  '103. Rohit Srivastava',
#  '104. Anson Paul',
#  '105. Tanay Misra',
#  '106. Narsinharao Rathod',
#  '107. Chattumala Naveen',
#  '108. Kartik Ekka',
#  '109. Jitesh Kumar Sethy',
#  '11. Bhavani Nanda',
#  '110. Amrendra Panday',
#  '111. Divyaranjan Parida',
#  '112. Sitaram Sahoo',
#  '113. Logesh Mohan',
#  '114. Shubhanshu Gupta',
#  '115. Anuj Saini',
#  '116. Harsh Joon',
#  '117. Ghanshyam Gupta',
#  '118. Anugya Chaubey',
#  '119. Subham Behera',
#  '12. Deepak Reddy',
#  '120. Nitin Hemdan',
#  '121. Surya Narayan',
#  '122. Prasant Gond',
#  '123. SHCD',
#  '124. Rajata Nayak',
#  '125. Adnan',
#  '126. Badri Mallick',
#  '127. Umesh Kumar',
#  '128. Kundan',
#  '129. Competitor Patent Watch',
#  '13. Dharma Teja',
#  '130. Bhavesh Bakshi',
#  '131. Kanchan Kumari',
#  '132. Vinay Mishra',
#  '133. Bhanumati Seervi',
# ...

# %%
document = Document("../documents/template_out.docx")

# %%
document.save("S:/7. Arun Reddy/1111/test.docx")

# %%
document.save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19284\261214626.py in <module>
# ----> 1 document.save("\\172.16.1.5/7. Arun Reddy/1111/test11.docx")
#
# C:\Anaconda\lib\site-packages\docx\document.py in save(self, path_or_stream)
#     133         a filesystem location (a string) or a file-like object.
#     134         """
# --> 135         self._part.save(path_or_stream)
#     136
#     137     @property
#
# C:\Anaconda\lib\site-packages\docx\parts\document.py in save(self, path_or_stream)
#     109         a filesystem location (a string) or a file-like object.
#     110         """
# --> 111         self.package.save(path_or_stream)
#     112
#     113     @property
#
# C:\Anaconda\lib\site-packages\docx\opc\package.py in save(self, pkg_file)
#     170         for part in self.parts:
#     171             part.before_marshal()
# ...

# %%
import socket
import re

# %%
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.settimeout(1)

# %%
s.connect_ex(())

# %%
# move report to common shared
